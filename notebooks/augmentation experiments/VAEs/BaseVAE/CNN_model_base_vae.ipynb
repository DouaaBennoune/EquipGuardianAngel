# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import seaborn as sns
from keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from tensorflow.keras import optimizers
from tensorflow.keras import regularizers
# Out:
# 2026-04-18 18:08:15.641964: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-18 18:08:15.778109: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-18 18:08:15.815248: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-18 18:08:16.346799: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib64:
# 2026-04-18 18:08:16.351426: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib64:
# 2026-04-18 18:08:16.351453: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
import numpy as np
n_splits=5
seq_length=44
# Load the data
data = np.load("/mnt/c/Users/PC/Downloads/AI/DeepLearning/Data Augmentation/VAEs/time_vae_generated_data.npy")
feat_dim=17
# Inspect shape
print(data.shape)
# Out:
# (5000, 44, 17)

# %%
data=data[:, :, 1:]
y=data[:,:,0]

# %%
print(data.shape)
# Out:
# (5000, 44, 16)

# %%
data=data.reshape(data.shape[0],-1)
print(data.shape)
# Out:
# (5000, 704)

# %%
scaler=StandardScaler()
data=scaler.fit_transform(data)

# %%
data=data.reshape(data.shape[0],seq_length,16)
print(data.shape)
# Out:
# (5000, 44, 16)

# %%
n_splits=5
seq_length=45
df=pd.read_csv('/mnt/c/Users/PC/Downloads/AI/DeepLearning/Data PreProcessing/CLEANED_DATA/train/train_FD001_cleaned.csv',sep=',')
test_df=pd.read_csv('/mnt/c/Users/PC/Downloads/AI/DeepLearning/FINAL transformer  PROJECT/data cleaning/test_FD001_cleaned.csv',sep=',')
df_time_warp=pd.read_csv('/mnt/c/Users/PC/Downloads/AI/DeepLearning/Data Augmentation/traditional techniques/time_warping_fd001.csv')
df_mag_warp=pd.read_csv('/mnt/c/Users/PC/Downloads/AI/DeepLearning/Data Augmentation/traditional techniques/magnitude_warping_fd001.csv')
df_scaling=pd.read_csv('/mnt/c/Users/PC/Downloads/AI/DeepLearning/Data Augmentation/traditional techniques/homogeneous_scaling_fd001.csv')
df_window=pd.read_csv('/mnt/c/Users/PC/Downloads/AI/DeepLearning/Data Augmentation/traditional techniques/window_permutation_fd001.csv')
rul_true=pd.read_csv('/mnt/c/Users/PC/Downloads/AI/DeepLearning/FINAL transformer  PROJECT/not ready datasets/not ready datasets/RUL_FD001.txt',header=None,names=["RUL"],sep=',')
feature_cols=[col for col in df.columns if not col in ['id','cycle','RUL','setting3']]

# %%
columns=['RUL' ,'cycle','setting1', 'setting2', 'setting3','sensor_2', 'sensor_3', 'sensor_4',
       'sensor_7', 'sensor_8', 'sensor_9', 'sensor_11', 'sensor_12',
       'sensor_13', 'sensor_14', 'sensor_15', 'sensor_17', 'sensor_20',
       'sensor_21', 'id']
df=df[columns]
df_time_warp=df_time_warp[columns]
df_mag_warp=df_mag_warp[columns]
df_scaling=df_scaling[columns]
df_window=df_window[columns]

# %%
df_final = pd.concat(
    [df, df_time_warp, df_mag_warp, df_scaling,df_window],
    ignore_index=True
)

print(df_final.shape)
# Out:
# (103116, 20)

# %%
df_final['RUL']=df_final['RUL'].clip(upper=125)

# %%
import tensorflow as tf
from tensorflow.keras import Sequential, layers, regularizers, optimizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

def CNN_FNN_Model(seq_length, n_features):
    model = Sequential()
    model.add(layers.Input(shape=(seq_length, n_features)))
    
    # --- BLOCK 1: Feature Extraction ---
    
    model.add(layers.Conv1D(filters=32, 
                            kernel_size=3, 
                            padding='same', 
                            activation='swish',
                            kernel_regularizer=regularizers.l2(1e-3)))
    model.add(layers.BatchNormalization())
    
    model.add(layers.Conv1D(filters=32, 
                            kernel_size=3, 
                            padding='same', 
                            activation='swish',
                            kernel_regularizer=regularizers.l2(1e-4)))
    model.add(layers.BatchNormalization())
    
    model.add(layers.MaxPooling1D(pool_size=2))
    model.add(layers.Dropout(0.3)) 

    # --- BLOCK 2: Feature Extraction ---
    model.add(layers.Conv1D(filters=64, 
                            kernel_size=3, 
                            padding='same', 
                            activation='swish',
                            kernel_regularizer=regularizers.l2(1e-4)))
    model.add(layers.BatchNormalization())
    
    model.add(layers.Conv1D(filters=64, 
                            kernel_size=3, 
                            padding='same', 
                            activation='swish',
                            kernel_regularizer=regularizers.l2(1e-4)))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.2))

    # --- BLOCK 3: The "bottleneck" ---
    # Crucial change: Use Flatten to preserve the temporal sequence!
    model.add(layers.Flatten()) 

    # --- BLOCK 4: FNN (Regression Head) ---
    model.add(layers.Dense(64, activation='swish'))
    model.add(layers.Dropout(0.3))
    
    model.add(layers.Dense(32, activation='swish'))
    
    # Output Layer: Linear activation for direct RUL prediction (unscaled target)
    # Or 'relu' since RUL cannot be negative
    model.add(layers.Dense(1, activation='relu'))

    # Compile
    # Switched loss to MSE to directly optimize for RMSE. 
    model.compile(
        optimizer=optimizers.Adam(learning_rate=0.001),
        loss='mse', 
        metrics=[tf.keras.metrics.RootMeanSquaredError(name='rmse'), 'mae']
    )
    
    return model

# %%
def train_model(model, X_train, y_train, X_val, y_val, epochs=100, batch_size=64):
    early_stop = EarlyStopping(
        monitor='val_loss', 
        patience=12, 
        restore_best_weights=True,
        verbose=1
    )
    lr_scheduler = ReduceLROnPlateau(
        monitor='val_loss', 
        factor=0.5, 
        patience=5, 
        min_lr=1e-5,
        verbose=1
    )
    
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size, # 64 is often the sweet spot for CMAPSS seq data
        callbacks=[lr_scheduler, early_stop],
        verbose=1
    )
    return history

# %%
def scaler_process(df,feature_cols):
    x=df[feature_cols]
    y=df['RUL']
    x_scaler=StandardScaler()
    x_scaled=x_scaler.fit_transform(x)
    indexes=df[feature_cols]
    scaled_df=pd.DataFrame(
        x_scaled,
        columns=feature_cols,
        index=indexes.index
    )
    scaled_df['cycle']=df['cycle']
    scaled_df['id']=df['id']
    y_clipped = y.clip(upper=125)
    scaled_df['RUL']=y_clipped/125.0
    
    return scaled_df , x_scaler

# %%
def scaler_test_process(df,scaler,feature_cols):

    x_scaled=scaler.transform(df[feature_cols])
    indexes=df[feature_cols]
    x_scaled=pd.DataFrame(
        x_scaled,
        columns=feature_cols,
        index=indexes.index
    )
    x_scaled['cycle']=df['cycle']
    x_scaled['id']=df['id']
    return x_scaled

# %%
def window_eng_sequences(df, seq_length, feature_cols):
    """
    Transforms a 2D dataframe into 3D array (Samples, Seq_Len, Features)
    using sliding window.
    """
    X, y = [], []

    for engine, engine_data in df.groupby('id'):
        if len(engine_data) < seq_length:
            continue
            
        engine_feat = engine_data[feature_cols].values
        engine_rul = engine_data['RUL'].values

        for i in range(len(engine_data) - seq_length + 1):
            X.append(engine_feat[i : i + seq_length])
            y.append(engine_rul[i + seq_length - 1])
            
    return np.array(X), np.array(y)

# %%
def gen_test_windows(df,seq_length, feature_cols,rul_true,RUL_MAX=125):
    X_test = []
    y_test = []

    for engine in df['id'].unique():
        engine_data = df[df['id'] == engine]

        if len(engine_data) >= seq_length:
            X_test.append(engine_data[feature_cols].values[-seq_length:])

            # CMAPSS ground truth is clipped & scaled
            rul = rul_true.loc[engine - 1].values[0]
            rul = min(rul, RUL_MAX) / RUL_MAX
            y_test.append(rul)

    return np.array(X_test), np.array(y_test)

# %%
def evaluate_model(model, X_test, y_test_scaled, RUL_MAX=125):

    y_pred_scaled = model.predict(X_test)
    y_pred_scaled = y_pred_scaled

    y_pred = y_pred_scaled * RUL_MAX

    y_true = y_test_scaled * RUL_MAX
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)

    print("\nModel Performance Metrics (Original RUL scale):")
    print(f"MSE:  {mse:.4f}")
    print(f"RMSE: {rmse:.4f}")
    print(f"MAE:  {mae:.4f}")
    print(f"R²:   {r2:.4f}")

    return y_pred, y_true

# %%
def plot_results(history,y_test_original,y_pred_original):
    fig , axes = plt.subplots(1 ,2,figsize=(14,4))
    axes[0].plot(history.history['loss'],label='Training Loss',linewidth=0.5)
    axes[0].plot(history.history['val_loss'], label='Validation Loss',linewidth=0.5)
    axes[0].set_title('Model Loss Over Epochs')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].grid(True)

    axes[1].plot(y_test_original,label='Actual',linewidth=2)
    axes[1].plot(y_pred_original,label='predictions',linewidth=2)
    axes[1].set_title('Actual vs Predicted Values')
    axes[1].set_xlabel('Sample')
    axes[1].set_ylabel('Value')
    axes[1].legend()
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()

# %%
def evaluate_model(model, X_test, y_test_scaled, RUL_MAX=125):

    y_pred_scaled = model.predict(X_test)
    y_pred_scaled = y_pred_scaled

    y_pred = y_pred_scaled * RUL_MAX
    y_true = y_test_scaled * RUL_MAX
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)

    print("\nModel Performance Metrics (Original RUL scale):")
    print(f"MSE:  {mse:.4f}")
    print(f"RMSE: {rmse:.4f}")
    print(f"MAE:  {mae:.4f}")
    print(f"R²:   {r2:.4f}")

    return y_pred, y_true

# %%
RUL_MAX = 125
#df=df_final.copy()
df_scaled,scaler=scaler_process(df,feature_cols)
df_scaled.to_csv('df_scaled.csv',index=False)
common_cols=[col for col in df_scaled.columns if not col in ['RUL']]
test_df=test_df[common_cols]

# %%
from sklearn.model_selection import train_test_split
unique_ids=df['id'].unique()
train_idx,val_idx=train_test_split(unique_ids,test_size=0.25,random_state=42)
train_engine_ids=train_idx
val_engine_ids=val_idx
train_df=df_scaled[df_scaled['id'].isin(train_engine_ids)]
val_df=df_scaled[df_scaled['id'].isin(val_engine_ids)]

# %%
print(df_scaled['RUL'])
# Out:
# 0        1.000
# 1        1.000
# 2        1.000
# 3        1.000
# 4        1.000
#          ...
# 20626    0.032
# 20627    0.024
# 20628    0.016
# 20629    0.008
# 20630    0.000
# Name: RUL, Length: 20631, dtype: float64

# %%
print(len(df_scaled.columns))
# Out:
# 19

# %%
len(feature_cols)
# Out:
# 16

# %%
test_scaled_features=scaler_test_process(test_df,scaler,feature_cols)

# %%
print(len(test_scaled_features.columns))
# Out:
# 18

# %%
test_scaled_df=test_scaled_features.copy()
id_col='id'
if id_col not in (test_scaled_df.columns):
    test_scaled_df['id'] = test_df['id'].values

# %%
seq_length=44
X_train,y_train=window_eng_sequences(train_df,seq_length,feature_cols)
X_val,y_val=window_eng_sequences(val_df,seq_length,feature_cols)
X_test,y_test=gen_test_windows(test_scaled_df, seq_length, feature_cols, rul_true, RUL_MAX=125)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (12344, 44, 16)
# (96, 44, 16)

# %%
X_train_aug = np.concatenate([X_train, data], axis=0)
print(X_train_aug.shape)
# Out:
# (17344, 44, 16)

# %%
# Reduce aug_y to one label per sample, e.g. the last timestep
aug_y_flat = y[:, -1]   # shape (5000,)

# Now both are 1-D
y_train_aug = np.concatenate([y_train, aug_y_flat], axis=0)
print(y_train_aug.shape)  # (21331,)
# Out:
# (17344,)

# %%
X_test_flat=X_test.reshape(X_test.shape[0],-1)

# %%
model = CNN_FNN_Model(seq_length=seq_length, n_features=len(feature_cols))
history=train_model(
    model,
    X_train_aug,y_train_aug,
    X_val,y_val,
    epochs=50,
    batch_size=128
)
# Out:
# 2026-04-18 18:08:19.164995: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-18 18:08:19.236854: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-18 18:08:19.236932: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-18 18:08:19.237749: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-18 18:08:19.239190: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-18 18:08:19.239272: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-18 18:08:19.239321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-18 18:08:20.520612: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-18 18:08:20.520773: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-18 18:08:20.520787: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-04-18 18:08:20.520857: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-18 18:08:20.520991: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5410 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Epoch 1/50
# 2026-04-18 18:08:23.438921: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2026-04-18 18:08:26.067185: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 136/136 [==============================] - 10s 36ms/step - loss: 0.1381 - rmse: 0.3211 - mae: 0.2051 - val_loss: 0.0953 - val_rmse: 0.2464 - val_mae: 0.2038 - lr: 0.0010
# Epoch 2/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0626 - rmse: 0.1695 - mae: 0.1157 - val_loss: 0.0646 - val_rmse: 0.1775 - val_mae: 0.1466 - lr: 0.0010
# Epoch 3/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0532 - rmse: 0.1446 - mae: 0.0985 - val_loss: 0.0461 - val_rmse: 0.1214 - val_mae: 0.0992 - lr: 0.0010
# Epoch 4/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0477 - rmse: 0.1316 - mae: 0.0888 - val_loss: 0.0450 - val_rmse: 0.1250 - val_mae: 0.0990 - lr: 0.0010
# Epoch 5/50
# 136/136 [==============================] - 2s 17ms/step - loss: 0.0438 - rmse: 0.1244 - mae: 0.0833 - val_loss: 0.0429 - val_rmse: 0.1247 - val_mae: 0.0973 - lr: 0.0010
# Epoch 6/50
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0403 - rmse: 0.1181 - mae: 0.0792 - val_loss: 0.0409 - val_rmse: 0.1249 - val_mae: 0.0966 - lr: 0.0010
# Epoch 7/50
# 136/136 [==============================] - 3s 23ms/step - loss: 0.0365 - rmse: 0.1104 - mae: 0.0738 - val_loss: 0.0377 - val_rmse: 0.1197 - val_mae: 0.0881 - lr: 0.0010
# Epoch 8/50
# 136/136 [==============================] - 2s 17ms/step - loss: 0.0337 - rmse: 0.1058 - mae: 0.0702 - val_loss: 0.0357 - val_rmse: 0.1189 - val_mae: 0.0869 - lr: 0.0010
# Epoch 9/50
# 136/136 [==============================] - 2s 18ms/step - loss: 0.0308 - rmse: 0.1004 - mae: 0.0663 - val_loss: 0.0358 - val_rmse: 0.1266 - val_mae: 0.0990 - lr: 0.0010
# Epoch 10/50
# 136/136 [==============================] - 3s 19ms/step - loss: 0.0284 - rmse: 0.0967 - mae: 0.0642 - val_loss: 0.0315 - val_rmse: 0.1154 - val_mae: 0.0926 - lr: 0.0010
# Epoch 11/50
# 136/136 [==============================] - 2s 17ms/step - loss: 0.0283 - rmse: 0.1043 - mae: 0.0652 - val_loss: 0.0444 - val_rmse: 0.1657 - val_mae: 0.1278 - lr: 0.0010
# Epoch 12/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0263 - rmse: 0.0993 - mae: 0.0647 - val_loss: 0.0342 - val_rmse: 0.1353 - val_mae: 0.1091 - lr: 0.0010
# Epoch 13/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0231 - rmse: 0.0885 - mae: 0.0581 - val_loss: 0.0431 - val_rmse: 0.1688 - val_mae: 0.1325 - lr: 0.0010
# Epoch 14/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0216 - rmse: 0.0866 - mae: 0.0565 - val_loss: 0.0348 - val_rmse: 0.1459 - val_mae: 0.1159 - lr: 0.0010
# Epoch 15/50
# 136/136 [==============================] - ETA: 0s - loss: 0.0194 - rmse: 0.0805 - mae: 0.0523
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 136/136 [==============================] - 4s 31ms/step - loss: 0.0194 - rmse: 0.0805 - mae: 0.0523 - val_loss: 0.0407 - val_rmse: 0.1681 - val_mae: 0.1357 - lr: 0.0010
# Epoch 16/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0182 - rmse: 0.0773 - mae: 0.0501 - val_loss: 0.0316 - val_rmse: 0.1403 - val_mae: 0.1132 - lr: 5.0000e-04
# Epoch 17/50
# 136/136 [==============================] - 2s 18ms/step - loss: 0.0172 - rmse: 0.0743 - mae: 0.0485 - val_loss: 0.0319 - val_rmse: 0.1431 - val_mae: 0.1093 - lr: 5.0000e-04
# Epoch 18/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0163 - rmse: 0.0720 - mae: 0.0467 - val_loss: 0.0317 - val_rmse: 0.1442 - val_mae: 0.1115 - lr: 5.0000e-04
# Epoch 19/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0160 - rmse: 0.0731 - mae: 0.0473 - val_loss: 0.0287 - val_rmse: 0.1352 - val_mae: 0.1013 - lr: 5.0000e-04
# Epoch 20/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0154 - rmse: 0.0724 - mae: 0.0466 - val_loss: 0.0303 - val_rmse: 0.1425 - val_mae: 0.1125 - lr: 5.0000e-04
# Epoch 21/50
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0149 - rmse: 0.0724 - mae: 0.0470 - val_loss: 0.0322 - val_rmse: 0.1507 - val_mae: 0.1218 - lr: 5.0000e-04
# Epoch 22/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0142 - rmse: 0.0706 - mae: 0.0457 - val_loss: 0.0473 - val_rmse: 0.1957 - val_mae: 0.1516 - lr: 5.0000e-04
# Epoch 23/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0138 - rmse: 0.0704 - mae: 0.0451 - val_loss: 0.0297 - val_rmse: 0.1452 - val_mae: 0.1112 - lr: 5.0000e-04
# Epoch 24/50
# 134/136 [============================>.] - ETA: 0s - loss: 0.0133 - rmse: 0.0699 - mae: 0.0453
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0133 - rmse: 0.0699 - mae: 0.0453 - val_loss: 0.0312 - val_rmse: 0.1516 - val_mae: 0.1169 - lr: 5.0000e-04
# Epoch 25/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0124 - rmse: 0.0658 - mae: 0.0426 - val_loss: 0.0298 - val_rmse: 0.1479 - val_mae: 0.1147 - lr: 2.5000e-04
# Epoch 26/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0119 - rmse: 0.0641 - mae: 0.0413 - val_loss: 0.0296 - val_rmse: 0.1480 - val_mae: 0.1119 - lr: 2.5000e-04
# Epoch 27/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0118 - rmse: 0.0645 - mae: 0.0416 - val_loss: 0.0296 - val_rmse: 0.1487 - val_mae: 0.1144 - lr: 2.5000e-04
# Epoch 28/50
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0115 - rmse: 0.0641 - mae: 0.0414 - val_loss: 0.0294 - val_rmse: 0.1489 - val_mae: 0.1146 - lr: 2.5000e-04
# Epoch 29/50
# 134/136 [============================>.] - ETA: 0s - loss: 0.0112 - rmse: 0.0637 - mae: 0.0409
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0112 - rmse: 0.0637 - mae: 0.0409 - val_loss: 0.0292 - val_rmse: 0.1489 - val_mae: 0.1181 - lr: 2.5000e-04
# Epoch 30/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0108 - rmse: 0.0618 - mae: 0.0399 - val_loss: 0.0298 - val_rmse: 0.1512 - val_mae: 0.1160 - lr: 1.2500e-04
# Epoch 31/50
# 136/136 [==============================] - 4s 28ms/step - loss: 0.0106 - rmse: 0.0609 - mae: 0.0393 - val_loss: 0.0278 - val_rmse: 0.1448 - val_mae: 0.1126 - lr: 1.2500e-04
# Epoch 32/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0106 - rmse: 0.0621 - mae: 0.0397 - val_loss: 0.0263 - val_rmse: 0.1400 - val_mae: 0.1077 - lr: 1.2500e-04
# Epoch 33/50
# 136/136 [==============================] - 2s 16ms/step - loss: 0.0103 - rmse: 0.0606 - mae: 0.0389 - val_loss: 0.0293 - val_rmse: 0.1507 - val_mae: 0.1175 - lr: 1.2500e-04
# Epoch 34/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0101 - rmse: 0.0598 - mae: 0.0387 - val_loss: 0.0277 - val_rmse: 0.1456 - val_mae: 0.1103 - lr: 1.2500e-04
# Epoch 35/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0101 - rmse: 0.0602 - mae: 0.0388 - val_loss: 0.0300 - val_rmse: 0.1537 - val_mae: 0.1142 - lr: 1.2500e-04
# Epoch 36/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0105 - rmse: 0.0642 - mae: 0.0399 - val_loss: 0.0282 - val_rmse: 0.1480 - val_mae: 0.1115 - lr: 1.2500e-04
# Epoch 37/50
# 132/136 [============================>.] - ETA: 0s - loss: 0.0098 - rmse: 0.0600 - mae: 0.0385
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0098 - rmse: 0.0599 - mae: 0.0385 - val_loss: 0.0275 - val_rmse: 0.1461 - val_mae: 0.1097 - lr: 1.2500e-04
# Epoch 38/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0096 - rmse: 0.0582 - mae: 0.0375 - val_loss: 0.0299 - val_rmse: 0.1542 - val_mae: 0.1149 - lr: 6.2500e-05
# Epoch 39/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0094 - rmse: 0.0571 - mae: 0.0368 - val_loss: 0.0281 - val_rmse: 0.1483 - val_mae: 0.1130 - lr: 6.2500e-05
# Epoch 40/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0093 - rmse: 0.0575 - mae: 0.0370 - val_loss: 0.0279 - val_rmse: 0.1480 - val_mae: 0.1147 - lr: 6.2500e-05
# Epoch 41/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0094 - rmse: 0.0585 - mae: 0.0376 - val_loss: 0.0295 - val_rmse: 0.1536 - val_mae: 0.1159 - lr: 6.2500e-05
# Epoch 42/50
# 133/136 [============================>.] - ETA: 0s - loss: 0.0093 - rmse: 0.0577 - mae: 0.0369
# Epoch 42: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0093 - rmse: 0.0578 - mae: 0.0369 - val_loss: 0.0264 - val_rmse: 0.1432 - val_mae: 0.1094 - lr: 6.2500e-05
# Epoch 43/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0091 - rmse: 0.0572 - mae: 0.0368 - val_loss: 0.0280 - val_rmse: 0.1488 - val_mae: 0.1120 - lr: 3.1250e-05
# Epoch 44/50
# 135/136 [============================>.] - ETA: 0s - loss: 0.0091 - rmse: 0.0571 - mae: 0.0367Restoring model weights from the end of the best epoch: 32.
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0091 - rmse: 0.0571 - mae: 0.0367 - val_loss: 0.0274 - val_rmse: 0.1468 - val_mae: 0.1120 - lr: 3.1250e-05
# Epoch 44: early stopping

# %%
y_pred_test, y_test = evaluate_model(model, X_test, y_test)
plot_results(history,y_test,y_pred_test)
# Out:
# 3/3 [==============================] - 0s 5ms/step
#
# Model Performance Metrics (Original RUL scale):
# MSE:  342.9280
# RMSE: 18.5183
# MAE:  14.6487
# R²:   0.7850

# %%
# 1. Initialize counters OUTSIDE the loop
pessimistic_count = 0
optimistic_count = 0

# 2. Use zip() to pair the lists
for pred, act in zip(y_pred_test, y_test):
    
    # 3. Compare
    if pred < act:
        pessimistic_count += 1  # Use += to save the value
    else:
        optimistic_count += 1

# 4. Print results
print(f"Pessimistic predictions: {pessimistic_count}")
print(f"Optimistic predictions: {optimistic_count}")

if pessimistic_count > optimistic_count:
    print(" Verdict: Model is Pessimistic (Safer for Maintenance)")
else:
    print(" Verdict: Model is Optimistic (Risky for Maintenance)")
# Out:
# Pessimistic predictions: 19
# Optimistic predictions: 77
#  Verdict: Model is Optimistic (Risky for Maintenance)

# %%
import joblib 

joblib.dump(model, "RF_model_FD001.pkl")
joblib.dump(scaler,"RF_Scaler_FD001.pkl")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://fe348fa1-d21e-473e-a750-ca3151d2ea66/assets
# INFO:tensorflow:Assets written to: ram://fe348fa1-d21e-473e-a750-ca3151d2ea66/assets
# ['RF_Scaler_FD001.pkl']
