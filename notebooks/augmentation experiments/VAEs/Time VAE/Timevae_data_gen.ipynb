# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import keras
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras

# %% [markdown]
# ### 1.import data

# %%
fd001=pd.read_csv('/mnt/c/Users/PC/Downloads/AI/DeepLearning/Data PreProcessing/CLEANED_DATA/train/train_FD001_cleaned.csv',sep=',')
fd002=pd.read_csv('/mnt/c/Users/PC/Downloads/AI/DeepLearning/Data PreProcessing/CLEANED_DATA/train/train_FD002_cleaned.csv',sep=',')
fd003=pd.read_csv('/mnt/c/Users/PC/Downloads/AI/DeepLearning/Data PreProcessing/CLEANED_DATA/train/train_FD003_cleaned.csv',sep=',')
fd004=pd.read_csv('/mnt/c/Users/PC/Downloads/AI/DeepLearning/Data PreProcessing/CLEANED_DATA/train/train_FD004_cleaned.csv',sep=',')

# %%
print(len(fd001.columns))
print(len(fd002.columns))
print(len(fd003.columns))
print(len(fd004.columns))
# Out:
# 20
# 20
# 20
# 20

# %%
test_df=pd.read_csv('/mnt/c/Users/PC/Downloads/AI/DeepLearning/FINAL transformer  PROJECT/data cleaning/test_FD001_cleaned.csv',sep=',')
rul_true=pd.read_csv('/mnt/c/Users/PC/Downloads/AI/DeepLearning/FINAL transformer  PROJECT/not ready datasets/not ready datasets/RUL_FD001.txt',header=None,names=["RUL"],sep=',')
print(rul_true)
print(fd001['id'])
# Out:
#     RUL
# 0   112
# 1    98
# 2    69
# 3    82
# 4    91
# ..  ...
# 95  137
# 96   82
# 97   59
# 98  117
# 99   20
#
# [100 rows x 1 columns]
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#         ...
# 20626    100
# 20627    100
# 20628    100
# 20629    100
# 20630    100
# Name: id, Length: 20631, dtype: int64

# %% [markdown]
# ### 2.data preprocessing

# %%
#scaling

def scaling_process(df):
    y=df['RUL']
    y_clipped = y.clip(upper=125)
    df['RUL']=y_clipped
    feature_cols=[col for col in df.columns if not col in ['id','cycle','setting3']]
    x=df[feature_cols]
    indexes=df[feature_cols]
    x_scaler=MinMaxScaler()
    x_scaled=x_scaler.fit_transform(x)
    scaled_df=pd.DataFrame(
        x_scaled,
        columns=feature_cols,
        index=indexes.index
    )
    scaled_df['id']=df['id']
    return scaled_df,x_scaler

# %%
#2.windowing
def windows(df,rul_true=None,seq_len=44):#seq len should be even number
    feature_cols=[col for col in df.columns if not col in ['id','cycle','setting3']]
    X=[]
    y=[]
    
    for engine ,engine_data in df.groupby('id'):
        engine_feats=engine_data[feature_cols].values
        if len(engine_data)>= seq_len:
            if 'RUL' in df.columns:
                engine_rul=engine_data['RUL'].values
            
                for i in range (len(engine_data) - seq_len+1):
                    X.append(engine_feats[i : i + seq_len])
                    
            else:
                
                X.append(engine_feats[- seq_len :])
                y.append(rul_true.loc[engine-1])

        

    return np.array(X),np.array(y)

# %%
fd001_scaled,fd001_scaler = scaling_process(fd001)
fd002_scaled,fd002_scaler = scaling_process(fd002)
fd003_scaled,fd003_scaler = scaling_process(fd003)
fd004_scaled,fd004_scaler = scaling_process(fd004)

# %%
x1_train,y1_train=windows(fd001_scaled)
x2_train,y2_train=windows(fd002_scaled)
x3_train,y3_train=windows(fd003_scaled)
x4_train,y4_train=windows(fd004_scaled)

# %%
print(f"fd001 Training data shape: {x1_train.shape}") 
print(f"fd002 Training data shape: {x2_train.shape}") 
print(f"fd003 Training data shape: {x3_train.shape}") 
print(f"fd004 Training data shape: {x4_train.shape}")
# Out:
# fd001 Training data shape: (16331, 44, 17)
# fd002 Training data shape: (42579, 44, 17)
# fd003 Training data shape: (20420, 44, 17)
# fd004 Training data shape: (50542, 44, 17)

# %% [markdown]
# ### 3.Initializing and Training the VAE

# %%
from VAE_base import BaseVariationalAutoencoder , Sampling

from TimeVAE import TimeVAE

# %%
seq_len=x1_train.shape[1]
feat_dim= x1_train.shape[2]
latent_dim = 32
batch_size= 32
hidden_layer_sizes=100

# %%
model = TimeVAE(seq_len=seq_len,
                feat_dim=feat_dim,
                latent_dim=latent_dim,
        hidden_layer_sizes=[50, 100, 200],
        trend_poly=0,
        custom_seas=None,
        use_residual_conn=True)

# %%
model = TimeVAE(seq_len=seq_len,
                feat_dim=feat_dim,
                latent_dim=latent_dim,
        hidden_layer_sizes=[50, 100, 200],
        trend_poly=0,
        custom_seas=None,
        use_residual_conn=True)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001))

model.fit_on_data(x1_train,max_epochs=500,verbose=1)
# Out:
# Epoch 1/500
# 1021/1021 [==============================] - ETA: 0s - loss: 111.5005 - reconstruction_loss: 13.0555 - kl_loss: 17.6275WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 10s 9ms/step - loss: 111.4469 - reconstruction_loss: 13.0555 - kl_loss: 17.6275 - lr: 0.0010
# Epoch 2/500
# 1021/1021 [==============================] - ETA: 0s - loss: 35.2366 - reconstruction_loss: 8.2988 - kl_loss: 8.9709WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 11s 10ms/step - loss: 35.2353 - reconstruction_loss: 8.2988 - kl_loss: 8.9709 - lr: 0.0010
# Epoch 3/500
# 1021/1021 [==============================] - ETA: 0s - loss: 31.0384 - reconstruction_loss: 7.9064 - kl_loss: 6.2542WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 9s 9ms/step - loss: 31.0374 - reconstruction_loss: 7.9064 - kl_loss: 6.2542 - lr: 0.0010
# Epoch 4/500
# 1020/1021 [============================>.] - ETA: 0s - loss: 27.2841 - reconstruction_loss: 7.1758 - kl_loss: 5.0771WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 8s 8ms/step - loss: 27.2827 - reconstruction_loss: 7.1758 - kl_loss: 5.0765 - lr: 0.0010
# Epoch 5/500
# 1020/1021 [============================>.] - ETA: 0s - loss: 24.9814 - reconstruction_loss: 6.9692 - kl_loss: 3.7406WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 8s 8ms/step - loss: 24.9807 - reconstruction_loss: 6.9687 - kl_loss: 3.7398 - lr: 0.0010
# Epoch 6/500
# 1021/1021 [==============================] - ETA: 0s - loss: 23.7882 - reconstruction_loss: 6.8871 - kl_loss: 2.8921WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 9s 9ms/step - loss: 23.7880 - reconstruction_loss: 6.8871 - kl_loss: 2.8921 - lr: 0.0010
# Epoch 7/500
# 1017/1021 [============================>.] - ETA: 0s - loss: 23.2239 - reconstruction_loss: 6.8227 - kl_loss: 2.7459WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 10s 10ms/step - loss: 23.2239 - reconstruction_loss: 6.8224 - kl_loss: 2.7462 - lr: 0.0010
# Epoch 8/500
# 1020/1021 [============================>.] - ETA: 0s - loss: 23.1037 - reconstruction_loss: 6.7769 - kl_loss: 2.7394WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 10s 9ms/step - loss: 23.1037 - reconstruction_loss: 6.7768 - kl_loss: 2.7391 - lr: 0.0010
# Epoch 9/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 23.0260 - reconstruction_loss: 6.7656 - kl_loss: 2.7374WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 10s 10ms/step - loss: 23.0260 - reconstruction_loss: 6.7653 - kl_loss: 2.7377 - lr: 0.0010
# Epoch 10/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.9565 - reconstruction_loss: 6.7487 - kl_loss: 2.7216WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 11s 11ms/step - loss: 22.9566 - reconstruction_loss: 6.7487 - kl_loss: 2.7212 - lr: 0.0010
# Epoch 11/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.9272 - reconstruction_loss: 6.7233 - kl_loss: 2.7489WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 10s 10ms/step - loss: 22.9272 - reconstruction_loss: 6.7233 - kl_loss: 2.7489 - lr: 0.0010
# Epoch 12/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.8275 - reconstruction_loss: 6.7120 - kl_loss: 2.7259WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 9s 9ms/step - loss: 22.8276 - reconstruction_loss: 6.7120 - kl_loss: 2.7254 - lr: 0.0010
# Epoch 13/500
# 1015/1021 [============================>.] - ETA: 0s - loss: 22.8473 - reconstruction_loss: 6.7045 - kl_loss: 2.7208WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 11s 11ms/step - loss: 22.8472 - reconstruction_loss: 6.7048 - kl_loss: 2.7200 - lr: 0.0010
# Epoch 14/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.7815 - reconstruction_loss: 6.6883 - kl_loss: 2.7449WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 9s 9ms/step - loss: 22.7815 - reconstruction_loss: 6.6883 - kl_loss: 2.7449 - lr: 0.0010
# Epoch 15/500
# 1017/1021 [============================>.] - ETA: 0s - loss: 22.7907 - reconstruction_loss: 6.6807 - kl_loss: 2.7459WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 9s 9ms/step - loss: 22.7907 - reconstruction_loss: 6.6806 - kl_loss: 2.7452 - lr: 0.0010
# Epoch 16/500
# 1016/1021 [============================>.] - ETA: 0s - loss: 22.7532 - reconstruction_loss: 6.6749 - kl_loss: 2.7286WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 10s 10ms/step - loss: 22.7532 - reconstruction_loss: 6.6759 - kl_loss: 2.7275 - lr: 0.0010
# Epoch 17/500
# 1015/1021 [============================>.] - ETA: 0s - loss: 22.7505 - reconstruction_loss: 6.6721 - kl_loss: 2.7190WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 9s 9ms/step - loss: 22.7504 - reconstruction_loss: 6.6723 - kl_loss: 2.7199 - lr: 0.0010
# Epoch 18/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.6838 - reconstruction_loss: 6.6611 - kl_loss: 2.7404WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 9s 8ms/step - loss: 22.6840 - reconstruction_loss: 6.6613 - kl_loss: 2.7399 - lr: 0.0010
# Epoch 19/500
# 1017/1021 [============================>.] - ETA: 0s - loss: 22.7051 - reconstruction_loss: 6.6612 - kl_loss: 2.7367WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 9s 9ms/step - loss: 22.7051 - reconstruction_loss: 6.6618 - kl_loss: 2.7359 - lr: 0.0010
# Epoch 20/500
# 1017/1021 [============================>.] - ETA: 0s - loss: 22.6663 - reconstruction_loss: 6.6555 - kl_loss: 2.7397WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 10s 10ms/step - loss: 22.6664 - reconstruction_loss: 6.6549 - kl_loss: 2.7392 - lr: 0.0010
# Epoch 21/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.7144 - reconstruction_loss: 6.6512 - kl_loss: 2.7354WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 10s 10ms/step - loss: 22.7143 - reconstruction_loss: 6.6512 - kl_loss: 2.7354 - lr: 0.0010
# Epoch 22/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.6545 - reconstruction_loss: 6.6469 - kl_loss: 2.7311WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 10s 10ms/step - loss: 22.6546 - reconstruction_loss: 6.6467 - kl_loss: 2.7316 - lr: 0.0010
# Epoch 23/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.6707 - reconstruction_loss: 6.6459 - kl_loss: 2.7381WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 10s 10ms/step - loss: 22.6707 - reconstruction_loss: 6.6466 - kl_loss: 2.7379 - lr: 0.0010
# Epoch 24/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.6911 - reconstruction_loss: 6.6452 - kl_loss: 2.7541WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 9s 9ms/step - loss: 22.6911 - reconstruction_loss: 6.6452 - kl_loss: 2.7541 - lr: 0.0010
# Epoch 25/500
# 1020/1021 [============================>.] - ETA: 0s - loss: 22.6608 - reconstruction_loss: 6.6429 - kl_loss: 2.7441WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 9s 9ms/step - loss: 22.6608 - reconstruction_loss: 6.6430 - kl_loss: 2.7437 - lr: 0.0010
# Epoch 26/500
# 1016/1021 [============================>.] - ETA: 0s - loss: 22.6742 - reconstruction_loss: 6.6354 - kl_loss: 2.7582WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 9s 9ms/step - loss: 22.6741 - reconstruction_loss: 6.6360 - kl_loss: 2.7578 - lr: 0.0010
# Epoch 27/500
# 1017/1021 [============================>.] - ETA: 0s - loss: 22.6650 - reconstruction_loss: 6.6384 - kl_loss: 2.7526WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 10s 10ms/step - loss: 22.6650 - reconstruction_loss: 6.6383 - kl_loss: 2.7532 - lr: 0.0010
# Epoch 28/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.6434 - reconstruction_loss: 6.6319 - kl_loss: 2.7636WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 9s 9ms/step - loss: 22.6434 - reconstruction_loss: 6.6319 - kl_loss: 2.7631 - lr: 0.0010
# Epoch 29/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.6305 - reconstruction_loss: 6.6293 - kl_loss: 2.7601WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 9s 9ms/step - loss: 22.6306 - reconstruction_loss: 6.6292 - kl_loss: 2.7602 - lr: 0.0010
# Epoch 30/500
# 1016/1021 [============================>.] - ETA: 0s - loss: 22.6411 - reconstruction_loss: 6.6290 - kl_loss: 2.7781WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 10s 10ms/step - loss: 22.6412 - reconstruction_loss: 6.6285 - kl_loss: 2.7787 - lr: 0.0010
# Epoch 31/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.6323 - reconstruction_loss: 6.6251 - kl_loss: 2.7507WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 10s 10ms/step - loss: 22.6323 - reconstruction_loss: 6.6251 - kl_loss: 2.7507 - lr: 0.0010
# Epoch 32/500
# 1016/1021 [============================>.] - ETA: 0s - loss: 22.6349 - reconstruction_loss: 6.6225 - kl_loss: 2.7560WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 9s 9ms/step - loss: 22.6348 - reconstruction_loss: 6.6223 - kl_loss: 2.7560 - lr: 0.0010
# Epoch 33/500
# 1016/1021 [============================>.] - ETA: 0s - loss: 22.6338 - reconstruction_loss: 6.6196 - kl_loss: 2.7592WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 10s 10ms/step - loss: 22.6337 - reconstruction_loss: 6.6195 - kl_loss: 2.7593 - lr: 0.0010
# Epoch 34/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.6282 - reconstruction_loss: 6.6190 - kl_loss: 2.7730WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 11s 11ms/step - loss: 22.6282 - reconstruction_loss: 6.6191 - kl_loss: 2.7730 - lr: 0.0010
# Epoch 35/500
# 1017/1021 [============================>.] - ETA: 0s - loss: 22.6152 - reconstruction_loss: 6.6183 - kl_loss: 2.7640WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 44s 43ms/step - loss: 22.6152 - reconstruction_loss: 6.6181 - kl_loss: 2.7640 - lr: 0.0010
# Epoch 36/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.6474 - reconstruction_loss: 6.6186 - kl_loss: 2.7793WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 71s 69ms/step - loss: 22.6474 - reconstruction_loss: 6.6187 - kl_loss: 2.7794 - lr: 0.0010
# Epoch 37/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.5966 - reconstruction_loss: 6.6137 - kl_loss: 2.7662WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 54s 53ms/step - loss: 22.5966 - reconstruction_loss: 6.6137 - kl_loss: 2.7662 - lr: 0.0010
# Epoch 38/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.5655 - reconstruction_loss: 6.6075 - kl_loss: 2.7551WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 52s 51ms/step - loss: 22.5655 - reconstruction_loss: 6.6075 - kl_loss: 2.7551 - lr: 0.0010
# Epoch 39/500
# 1020/1021 [============================>.] - ETA: 0s - loss: 22.5705 - reconstruction_loss: 6.6050 - kl_loss: 2.7624WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 49s 48ms/step - loss: 22.5705 - reconstruction_loss: 6.6051 - kl_loss: 2.7626 - lr: 0.0010
# Epoch 40/500
# 1016/1021 [============================>.] - ETA: 0s - loss: 22.5774 - reconstruction_loss: 6.6052 - kl_loss: 2.7706WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 54s 53ms/step - loss: 22.5775 - reconstruction_loss: 6.6049 - kl_loss: 2.7703 - lr: 0.0010
# Epoch 41/500
# 1020/1021 [============================>.] - ETA: 0s - loss: 22.5701 - reconstruction_loss: 6.6059 - kl_loss: 2.7620WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 54s 53ms/step - loss: 22.5701 - reconstruction_loss: 6.6061 - kl_loss: 2.7623 - lr: 0.0010
# Epoch 42/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.5895 - reconstruction_loss: 6.6034 - kl_loss: 2.7781WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 57s 56ms/step - loss: 22.5895 - reconstruction_loss: 6.6039 - kl_loss: 2.7781 - lr: 0.0010
# Epoch 43/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.5860 - reconstruction_loss: 6.6078 - kl_loss: 2.7776WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 49s 48ms/step - loss: 22.5860 - reconstruction_loss: 6.6078 - kl_loss: 2.7776 - lr: 0.0010
# Epoch 44/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.6013 - reconstruction_loss: 6.6030 - kl_loss: 2.7824WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 48s 47ms/step - loss: 22.6013 - reconstruction_loss: 6.6026 - kl_loss: 2.7819 - lr: 0.0010
# Epoch 45/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.5844 - reconstruction_loss: 6.6018 - kl_loss: 2.7902WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 47s 46ms/step - loss: 22.5844 - reconstruction_loss: 6.6014 - kl_loss: 2.7902 - lr: 0.0010
# Epoch 46/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.5574 - reconstruction_loss: 6.5982 - kl_loss: 2.7883WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 45s 44ms/step - loss: 22.5575 - reconstruction_loss: 6.5982 - kl_loss: 2.7891 - lr: 0.0010
# Epoch 47/500
# 1016/1021 [============================>.] - ETA: 0s - loss: 22.5548 - reconstruction_loss: 6.5988 - kl_loss: 2.7824WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 47s 46ms/step - loss: 22.5550 - reconstruction_loss: 6.5991 - kl_loss: 2.7819 - lr: 0.0010
# Epoch 48/500
# 1020/1021 [============================>.] - ETA: 0s - loss: 22.5592 - reconstruction_loss: 6.5985 - kl_loss: 2.7876WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 55s 53ms/step - loss: 22.5592 - reconstruction_loss: 6.5987 - kl_loss: 2.7875 - lr: 0.0010
# Epoch 49/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.6238 - reconstruction_loss: 6.6040 - kl_loss: 2.8009WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 53s 51ms/step - loss: 22.6238 - reconstruction_loss: 6.6040 - kl_loss: 2.8009 - lr: 0.0010
# Epoch 50/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.5492 - reconstruction_loss: 6.5992 - kl_loss: 2.7824WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 54s 53ms/step - loss: 22.5492 - reconstruction_loss: 6.5992 - kl_loss: 2.7824 - lr: 0.0010
# Epoch 51/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.5917 - reconstruction_loss: 6.5989 - kl_loss: 2.7949WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 45s 44ms/step - loss: 22.5917 - reconstruction_loss: 6.5989 - kl_loss: 2.7958 - lr: 0.0010
# Epoch 52/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.5880 - reconstruction_loss: 6.5937 - kl_loss: 2.7937WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 49s 48ms/step - loss: 22.5880 - reconstruction_loss: 6.5937 - kl_loss: 2.7937 - lr: 0.0010
# Epoch 53/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.5719 - reconstruction_loss: 6.5922 - kl_loss: 2.7867WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 46s 45ms/step - loss: 22.5718 - reconstruction_loss: 6.5922 - kl_loss: 2.7871 - lr: 0.0010
# Epoch 54/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.5539 - reconstruction_loss: 6.5925 - kl_loss: 2.7944WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 43s 42ms/step - loss: 22.5539 - reconstruction_loss: 6.5925 - kl_loss: 2.7944 - lr: 0.0010
# Epoch 55/500
# 1016/1021 [============================>.] - ETA: 0s - loss: 22.5532 - reconstruction_loss: 6.5950 - kl_loss: 2.7664WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 49s 48ms/step - loss: 22.5532 - reconstruction_loss: 6.5948 - kl_loss: 2.7672 - lr: 0.0010
# Epoch 56/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.5863 - reconstruction_loss: 6.5924 - kl_loss: 2.7755WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 44s 43ms/step - loss: 22.5862 - reconstruction_loss: 6.5922 - kl_loss: 2.7754 - lr: 0.0010
# Epoch 57/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.5906 - reconstruction_loss: 6.5951 - kl_loss: 2.7816WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 52s 51ms/step - loss: 22.5905 - reconstruction_loss: 6.5948 - kl_loss: 2.7823 - lr: 0.0010
# Epoch 58/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.5852 - reconstruction_loss: 6.5900 - kl_loss: 2.7880WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 49s 48ms/step - loss: 22.5851 - reconstruction_loss: 6.5903 - kl_loss: 2.7874 - lr: 0.0010
# Epoch 59/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.5499 - reconstruction_loss: 6.5933 - kl_loss: 2.8006WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 48s 47ms/step - loss: 22.5500 - reconstruction_loss: 6.5933 - kl_loss: 2.8006 - lr: 0.0010
# Epoch 60/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.5646 - reconstruction_loss: 6.5926 - kl_loss: 2.7869WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 48s 47ms/step - loss: 22.5646 - reconstruction_loss: 6.5925 - kl_loss: 2.7870 - lr: 0.0010
# Epoch 61/500
# 1017/1021 [============================>.] - ETA: 0s - loss: 22.5988 - reconstruction_loss: 6.5934 - kl_loss: 2.7964WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 48s 47ms/step - loss: 22.5987 - reconstruction_loss: 6.5936 - kl_loss: 2.7963 - lr: 0.0010
# Epoch 62/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.5582 - reconstruction_loss: 6.5863 - kl_loss: 2.7883WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 48s 47ms/step - loss: 22.5582 - reconstruction_loss: 6.5869 - kl_loss: 2.7879 - lr: 0.0010
# Epoch 63/500
# 1017/1021 [============================>.] - ETA: 0s - loss: 22.5871 - reconstruction_loss: 6.5886 - kl_loss: 2.7944WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 48s 47ms/step - loss: 22.5870 - reconstruction_loss: 6.5884 - kl_loss: 2.7946 - lr: 0.0010
# Epoch 64/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.5798 - reconstruction_loss: 6.5887 - kl_loss: 2.7919WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 44s 43ms/step - loss: 22.5798 - reconstruction_loss: 6.5883 - kl_loss: 2.7916 - lr: 0.0010
# Epoch 65/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.5360 - reconstruction_loss: 6.5909 - kl_loss: 2.7837WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 72s 71ms/step - loss: 22.5361 - reconstruction_loss: 6.5907 - kl_loss: 2.7843 - lr: 0.0010
# Epoch 66/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.5518 - reconstruction_loss: 6.5876 - kl_loss: 2.7987WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 56s 55ms/step - loss: 22.5519 - reconstruction_loss: 6.5882 - kl_loss: 2.7985 - lr: 0.0010
# Epoch 67/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.5318 - reconstruction_loss: 6.5825 - kl_loss: 2.7874WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 53s 52ms/step - loss: 22.5318 - reconstruction_loss: 6.5825 - kl_loss: 2.7874 - lr: 0.0010
# Epoch 68/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.5454 - reconstruction_loss: 6.5842 - kl_loss: 2.7785WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 49s 48ms/step - loss: 22.5454 - reconstruction_loss: 6.5841 - kl_loss: 2.7786 - lr: 0.0010
# Epoch 69/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.5481 - reconstruction_loss: 6.5821 - kl_loss: 2.7933WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 49s 48ms/step - loss: 22.5481 - reconstruction_loss: 6.5815 - kl_loss: 2.7930 - lr: 0.0010
# Epoch 70/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.5610 - reconstruction_loss: 6.5814 - kl_loss: 2.8113WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 54s 53ms/step - loss: 22.5610 - reconstruction_loss: 6.5818 - kl_loss: 2.8106 - lr: 0.0010
# Epoch 71/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.5397 - reconstruction_loss: 6.5838 - kl_loss: 2.7977WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 44s 43ms/step - loss: 22.5398 - reconstruction_loss: 6.5839 - kl_loss: 2.7971 - lr: 0.0010
# Epoch 72/500
# 1020/1021 [============================>.] - ETA: 0s - loss: 22.5479 - reconstruction_loss: 6.5808 - kl_loss: 2.8146WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 48s 47ms/step - loss: 22.5480 - reconstruction_loss: 6.5808 - kl_loss: 2.8147 - lr: 0.0010
# Epoch 73/500
# 1020/1021 [============================>.] - ETA: 0s - loss: 22.5686 - reconstruction_loss: 6.5871 - kl_loss: 2.8008WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 48s 47ms/step - loss: 22.5686 - reconstruction_loss: 6.5872 - kl_loss: 2.8014 - lr: 0.0010
# Epoch 74/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.5344 - reconstruction_loss: 6.5805 - kl_loss: 2.8001WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 44s 43ms/step - loss: 22.5344 - reconstruction_loss: 6.5804 - kl_loss: 2.8005 - lr: 0.0010
# Epoch 75/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.5500 - reconstruction_loss: 6.5834 - kl_loss: 2.8036WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 54s 53ms/step - loss: 22.5501 - reconstruction_loss: 6.5835 - kl_loss: 2.8036 - lr: 0.0010
# Epoch 76/500
# 1016/1021 [============================>.] - ETA: 0s - loss: 22.5589 - reconstruction_loss: 6.5816 - kl_loss: 2.8062WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 50s 49ms/step - loss: 22.5588 - reconstruction_loss: 6.5812 - kl_loss: 2.8059 - lr: 0.0010
# Epoch 77/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.4842 - reconstruction_loss: 6.5746 - kl_loss: 2.7939WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 47s 46ms/step - loss: 22.4843 - reconstruction_loss: 6.5751 - kl_loss: 2.7936 - lr: 0.0010
# Epoch 78/500
# 1017/1021 [============================>.] - ETA: 0s - loss: 22.5205 - reconstruction_loss: 6.5697 - kl_loss: 2.8174WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 47s 47ms/step - loss: 22.5205 - reconstruction_loss: 6.5698 - kl_loss: 2.8167 - lr: 0.0010
# Epoch 79/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.5348 - reconstruction_loss: 6.5762 - kl_loss: 2.8155WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 42s 41ms/step - loss: 22.5348 - reconstruction_loss: 6.5765 - kl_loss: 2.8159 - lr: 0.0010
# Epoch 80/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.5183 - reconstruction_loss: 6.5720 - kl_loss: 2.8220WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 43s 42ms/step - loss: 22.5183 - reconstruction_loss: 6.5720 - kl_loss: 2.8220 - lr: 0.0010
# Epoch 81/500
# 1020/1021 [============================>.] - ETA: 0s - loss: 22.5123 - reconstruction_loss: 6.5679 - kl_loss: 2.8216WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 42s 41ms/step - loss: 22.5124 - reconstruction_loss: 6.5681 - kl_loss: 2.8216 - lr: 0.0010
# Epoch 82/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.5269 - reconstruction_loss: 6.5708 - kl_loss: 2.8140WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 38s 37ms/step - loss: 22.5269 - reconstruction_loss: 6.5708 - kl_loss: 2.8140 - lr: 0.0010
# Epoch 83/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.5435 - reconstruction_loss: 6.5716 - kl_loss: 2.8247WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 38s 37ms/step - loss: 22.5435 - reconstruction_loss: 6.5716 - kl_loss: 2.8247 - lr: 0.0010
# Epoch 84/500
# ...
# 1021/1021 [==============================] - 51s 50ms/step - loss: 22.5203 - reconstruction_loss: 6.5584 - kl_loss: 2.8375 - lr: 0.0010
# Epoch 146/500
# 1016/1021 [============================>.] - ETA: 0s - loss: 22.5134 - reconstruction_loss: 6.5618 - kl_loss: 2.8256WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 50s 49ms/step - loss: 22.5134 - reconstruction_loss: 6.5619 - kl_loss: 2.8260 - lr: 0.0010
# Epoch 147/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.5101 - reconstruction_loss: 6.5572 - kl_loss: 2.8294WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 51s 50ms/step - loss: 22.5101 - reconstruction_loss: 6.5572 - kl_loss: 2.8294 - lr: 0.0010
# Epoch 148/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.4928 - reconstruction_loss: 6.5643 - kl_loss: 2.8160WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 56s 55ms/step - loss: 22.4928 - reconstruction_loss: 6.5643 - kl_loss: 2.8160 - lr: 0.0010
# Epoch 149/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.5123 - reconstruction_loss: 6.5597 - kl_loss: 2.8273WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 61s 60ms/step - loss: 22.5123 - reconstruction_loss: 6.5600 - kl_loss: 2.8274 - lr: 0.0010
# Epoch 150/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.5127 - reconstruction_loss: 6.5575 - kl_loss: 2.8381WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 63s 61ms/step - loss: 22.5127 - reconstruction_loss: 6.5573 - kl_loss: 2.8382 - lr: 0.0010
# Epoch 151/500
# 1020/1021 [============================>.] - ETA: 0s - loss: 22.5191 - reconstruction_loss: 6.5609 - kl_loss: 2.8252WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 60s 59ms/step - loss: 22.5191 - reconstruction_loss: 6.5610 - kl_loss: 2.8249 - lr: 0.0010
# Epoch 152/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.5115 - reconstruction_loss: 6.5541 - kl_loss: 2.8313WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 56s 55ms/step - loss: 22.5114 - reconstruction_loss: 6.5543 - kl_loss: 2.8306 - lr: 0.0010
# Epoch 153/500
# 1020/1021 [============================>.] - ETA: 0s - loss: 22.5244 - reconstruction_loss: 6.5568 - kl_loss: 2.8395WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 52s 51ms/step - loss: 22.5244 - reconstruction_loss: 6.5570 - kl_loss: 2.8398 - lr: 0.0010
# Epoch 154/500
# 1017/1021 [============================>.] - ETA: 0s - loss: 22.5114 - reconstruction_loss: 6.5573 - kl_loss: 2.8383WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 49s 48ms/step - loss: 22.5114 - reconstruction_loss: 6.5570 - kl_loss: 2.8383 - lr: 0.0010
# Epoch 155/500
# 1021/1021 [==============================] - ETA: 0s - loss: 22.4825 - reconstruction_loss: 6.5587 - kl_loss: 2.8289WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 51s 50ms/step - loss: 22.4825 - reconstruction_loss: 6.5587 - kl_loss: 2.8289 - lr: 0.0010
# Epoch 156/500
# 1020/1021 [============================>.] - ETA: 0s - loss: 22.4717 - reconstruction_loss: 6.5609 - kl_loss: 2.8164WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 56s 55ms/step - loss: 22.4718 - reconstruction_loss: 6.5608 - kl_loss: 2.8167 - lr: 0.0010
# Epoch 157/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.4787 - reconstruction_loss: 6.5585 - kl_loss: 2.8140WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 59s 58ms/step - loss: 22.4787 - reconstruction_loss: 6.5585 - kl_loss: 2.8145 - lr: 0.0010
# Epoch 158/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.4956 - reconstruction_loss: 6.5568 - kl_loss: 2.8310WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 16s 16ms/step - loss: 22.4956 - reconstruction_loss: 6.5565 - kl_loss: 2.8307 - lr: 0.0010
# Epoch 159/500
# 1018/1021 [============================>.] - ETA: 0s - loss: 22.5056 - reconstruction_loss: 6.5530 - kl_loss: 2.8356WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 21s 21ms/step - loss: 22.5056 - reconstruction_loss: 6.5528 - kl_loss: 2.8352 - lr: 0.0010
# Epoch 160/500
# 1019/1021 [============================>.] - ETA: 0s - loss: 22.4666 - reconstruction_loss: 6.5515 - kl_loss: 2.8195WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 14s 13ms/step - loss: 22.4667 - reconstruction_loss: 6.5519 - kl_loss: 2.8198 - lr: 0.0010
# Epoch 161/500
# 1017/1021 [============================>.] - ETA: 0s - loss: 22.4959 - reconstruction_loss: 6.5562 - kl_loss: 2.8231WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 16s 16ms/step - loss: 22.4959 - reconstruction_loss: 6.5554 - kl_loss: 2.8227 - lr: 0.0010
# Epoch 162/500
# 1020/1021 [============================>.] - ETA: 0s - loss: 22.4745 - reconstruction_loss: 6.5534 - kl_loss: 2.8309WARNING:tensorflow:Early stopping conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `total_loss` which is not available. Available metrics are: loss,reconstruction_loss,kl_loss,lr
# 1021/1021 [==============================] - 15s 15ms/step - loss: 22.4745 - reconstruction_loss: 6.5536 - kl_loss: 2.8308 - lr: 0.0010
# Epoch 163/500
#   16/1021 [..............................] - ETA: 19s - loss: 22.1736 - reconstruction_loss: 6.5040 - kl_loss: 2.7556
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 10
#       1 model = TimeVAE(seq_len=seq_len,
#       2                 feat_dim=feat_dim,
#       3                 latent_dim=latent_dim,
#    (...)
#       6         custom_seas=None,
#       7         use_residual_conn=True)
#       8 model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001))
# ---> 10 model.fit_on_data(x1_train,max_epochs=500,verbose=1)
#
# File /mnt/c/Users/PC/Downloads/AI/DeepLearning/Data Augmentation/VAEs/VAE_base.py:103, in BaseVariationalAutoencoder.fit_on_data(self, train_data, max_epochs, verbose)
#      99 early_stopping=EarlyStopping(monitor="total_loss",min_delta=1e-2,patience=50,mode="min")
#     100 reduce_lr = ReduceLROnPlateau(
#     101     monitor="total_loss",factor=0.5,patience=30, mode="min"
#     102 )
# --> 103 self.fit(
#     104     train_data,
#     105     batch_size=self.batch_size,
#     106     epochs=max_epochs,
#     107     verbose=verbose,
#     108     callbacks=[early_stopping,reduce_lr]
#     109
#     110 )
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.10/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
trainable_params , non_trainable_params , total_params= model.get_num_trainable_variables()
print(f"trainable parameters : {trainable_params }")
print(f"non trainable parameters : {non_trainable_params }")
print(f"total parameters : {total_params }")
# Out:
# trainable parameters : 884064
# non trainable parameters : 6
# total parameters : 884070

# %% [markdown]
# ### 4.Saving and Loading

# %%
model.save("TimeVAE_full.h5")

# %%
import os
model_dir= os.getcwd()
model.save(model_dir)
model.save_weights(model_dir)
model.load_weights(model_dir)

# %%
import os

# Make sure the file exists
print(os.path.exists("TimeVAE_encoder_wts.h5"))  # should print True

# Correct path if needed
encoder_wts_path = os.path.join(model_dir, "TimeVAE_encoder_wts.h5")

# Load into the right sub-model
model.encoder.load_weights(encoder_wts_path)
# Out:
# True
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[41], line 10
#       7 encoder_wts_path = os.path.join(model_dir, "TimeVAE_encoder_wts.h5")
#       9 # Load into the right sub-model
# ---> 10 model.encoder.load_weights(encoder_wts_path)
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.local/lib/python3.10/site-packages/h5py/_hl/files.py:564, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     555     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     556                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     557                      alignment_threshold=alignment_threshold,
#     558                      alignment_interval=alignment_interval,
#     559                      meta_block_size=meta_block_size,
#     560                      **kwds)
#     561     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     562                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     563                      fs_page_size=fs_page_size)
# --> 564     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     566 if isinstance(libver, tuple):
#     567     self._libver = libver
#
# File ~/.local/lib/python3.10/site-packages/h5py/_hl/files.py:238, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     236     if swmr and swmr_support:
#     237         flags |= h5f.ACC_SWMR_READ
# --> 238     fid = h5f.open(name, flags, fapl=fapl)
#     239 elif mode == 'r+':
#     240     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:57, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:102, in h5py.h5f.open()
#
# OSError: Unable to synchronously open file (file signature not found)

# %% [markdown]
# ### 5.Generating Synthetic Data

# %%
num_samples=5000
samples=model.get_prior_samples(num_samples=num_samples)
print(f"Shape of generated data: {samples.shape}") 

# 2. Inverse Transform back to real-world physics
samples_2D=samples.reshape(-1,feat_dim)
samples_T=fd001_scaler.inverse_transform(samples_2D)

samples_3D=samples_T.reshape(num_samples,seq_len,feat_dim)
# Out:
# Shape of generated data: (5000, 44, 17)

# %%
# 2. Inverse Transform back to real-world physics
x1_train_2D=x1_train.reshape(-1,feat_dim)
x1_train_T=fd001_scaler.inverse_transform(x1_train_2D)
num_samples_real=x1_train.shape[0]
x1_train_3D=x1_train_T.reshape(num_samples_real,seq_len,feat_dim)

# %%
import joblib
np.save("time_vae_generated_data.npy", samples_3D)
joblib.dump(fd001_scaler,"time_vae_scaler_fd001.pkl")
# Out:
# ['time_vae_scaler_fd001.pkl']

# %%
samples_3D = np.load("time_vae_generated_data.npy")

# %% [markdown]
# ## Evaluation of the synthetic data
# Wasserstein Distance (WD):
# Good: < 0.05 (Distributions are virtually identical).
# Bad: > 0.20 (The VAE failed to capture the upper and lower limits of the sensors; the synthetic engines might be generating impossible temperatures).
#
# Mean Correlation Error:
# Good: < 0.10. The heatmap should look almost entirely white/very pale pink. This means if Sensor A and B move together in real life, they also move together in the synthetic data.
# Bad: > 0.30. If the heatmap has dark red squares, it means the VAE is breaking physics (e.g., generating high temperatures with low pressure, which might be thermodynamically impossible).
#
# Rate of Change (Derivatives):
# If the red curve is much wider than the blue curve, your synthetic data is too "noisy" or "jittery" (jumping up and down wildly between cycles).
# If the red curve perfectly matches the blue curve, your VAE successfully learned the exact, smooth physical rate of engine degradation.

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import wasserstein_distance

# %%
def flatten_data(data):
    """Flattens 3D time-series data to 2D for statistical comparison."""
    return data.reshape(-1, data.shape[2])

# %%
def plot_all_feature_distributions(real_data, synthetic_data, feature_names):
    # Flatten the 3D data to 2D
    real_2d = real_data.reshape(-1, real_data.shape[2])
    synth_2d = synthetic_data.reshape(-1, synthetic_data.shape[2])
    num_features = real_2d.shape[1]
    
    # Calculate a dynamic grid size (4 columns wide)
    cols = 4
    rows = math.ceil(num_features / cols)
    
    # Create the figure
    fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
    axes = axes.flatten() # Flatten axes to loop through them easily
    
    w_distances =[]
    
    for i in range(num_features):
        # Calculate Wasserstein Distance
        wd = wasserstein_distance(real_2d[:, i], synth_2d[:, i])
        w_distances.append(wd)
        
        # Plot KDEs
        sns.kdeplot(real_2d[:, i], ax=axes[i], fill=True, color='blue', label='Real')
        sns.kdeplot(synth_2d[:, i], ax=axes[i], fill=True, color='red', label='Synthetic')
        
        # Set Title and Legend
        name = feature_names[i] if feature_names else f"Sensor {i}"
        axes[i].set_title(f"{name} (WD: {wd:.4f})")
        axes[i].legend()
        
    # If the number of features isn't perfectly divisible by 4, 
    # we need to hide the empty, unused subplots at the end.
    for j in range(num_features, len(axes)):
        fig.delaxes(axes[j])
        
    plt.tight_layout()
    plt.show()

# %%
def plot_correlation_difference(real_data, synthetic_data):
    real_2d = flatten_data(real_data)
    synth_2d = flatten_data(synthetic_data)
    
    # Calculate correlation matrices
    real_corr = np.corrcoef(real_2d, rowvar=False)
    synth_corr = np.corrcoef(synth_2d, rowvar=False)
    
    # Calculate the absolute difference between them
    corr_diff = np.abs(real_corr - synth_corr)
    
    # Mean Error in Correlation (Physics Score)
    mean_diff = np.mean(corr_diff)
    print(f"Mean Correlation Error (Closer to 0 is better physics): {mean_diff:.4f}")
    
    plt.figure(figsize=(8, 6))
    sns.heatmap(corr_diff, cmap="Reds", vmin=0, vmax=1)
    plt.title(f"Correlation Error Heatmap (Mean Error: {mean_diff:.4f})")
    plt.xlabel("Sensors")
    plt.ylabel("Sensors")
    plt.show()

# %%
def compare_temporal_derivatives(real_data, synthetic_data, sensor_idx=0):
    # Calculate step-to-step changes (Current cycle minus Previous cycle)
    real_diff = np.diff(real_data, axis=1)      # Shape: (Batch, 43, Features)
    synth_diff = np.diff(synthetic_data, axis=1)
    
    # Flatten just the specific sensor
    real_diff_flat = real_diff[:, :, sensor_idx].flatten()
    synth_diff_flat = synth_diff[:, :, sensor_idx].flatten()
    
    plt.figure(figsize=(8, 5))
    sns.kdeplot(real_diff_flat, fill=True, color='blue', label='Real Rate of Change')
    sns.kdeplot(synth_diff_flat, fill=True, color='red', label='Synthetic Rate of Change')
    plt.title(f"Physics Check: Temporal Rate of Change (Sensor {sensor_idx})")
    plt.xlabel("Step-to-Step Change (Delta)")
    plt.legend()
    plt.show()

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

   
def visualization (ori_data, generated_data, analysis):
  """Using PCA or tSNE for generated and original data visualization.
  
  Args:
    - ori_data: original data
    - generated_data: generated synthetic data
    - analysis: tsne or pca
  """  
  # Analysis sample size (for faster computation)
  anal_sample_no = min([1000, len(generated_data)])
  idx = np.random.permutation(len(generated_data))[:anal_sample_no]
    
  # Data preprocessing
  ori_data = np.asarray(ori_data)
  generated_data = np.asarray(generated_data)  
  
  ori_data = ori_data[idx]
  generated_data = generated_data[idx]
  
  no, seq_len, dim = ori_data.shape  
  
  for i in range(anal_sample_no):
    if (i == 0):
      prep_data = np.reshape(np.mean(ori_data[0,:,:], 1), [1,seq_len])
      prep_data_hat = np.reshape(np.mean(generated_data[0,:,:],1), [1,seq_len])
    else:
      prep_data = np.concatenate((prep_data, 
                                  np.reshape(np.mean(ori_data[i,:,:],1), [1,seq_len])))
      prep_data_hat = np.concatenate((prep_data_hat, 
                                      np.reshape(np.mean(generated_data[i,:,:],1), [1,seq_len])))
    
  # Visualization parameter        
  colors = ["red" for i in range(anal_sample_no)] + ["blue" for i in range(anal_sample_no)]    
    
  if analysis == 'pca':
    # PCA Analysis
    pca = PCA(n_components = 2)
    pca.fit(prep_data)
    pca_results = pca.transform(prep_data)
    pca_hat_results = pca.transform(prep_data_hat)
    
    # Plotting
    f, ax = plt.subplots(1)    
    plt.scatter(pca_results[:,0], pca_results[:,1],
                c = colors[:anal_sample_no], alpha = 0.2, label = "Original")
    plt.scatter(pca_hat_results[:,0], pca_hat_results[:,1], 
                c = colors[anal_sample_no:], alpha = 0.2, label = "Synthetic")
  
    ax.legend()  
    plt.title('PCA plot')
    plt.xlabel('x-pca')
    plt.ylabel('y_pca')
    plt.show()
    
  elif analysis == 'tsne':
    
    # Do t-SNE Analysis together       
    prep_data_final = np.concatenate((prep_data, prep_data_hat), axis = 0)
    
    # TSNE anlaysis
    tsne = TSNE(n_components = 2, verbose = 1, perplexity = 40)
    tsne_results = tsne.fit_transform(prep_data_final)
      
    # Plotting
    f, ax = plt.subplots(1)
      
    plt.scatter(tsne_results[:anal_sample_no,0], tsne_results[:anal_sample_no,1], 
                c = colors[:anal_sample_no], alpha = 0.2, label = "Original")
    plt.scatter(tsne_results[anal_sample_no:,0], tsne_results[anal_sample_no:,1], 
                c = colors[anal_sample_no:], alpha = 0.2, label = "Synthetic")
  
    ax.legend()
      
    plt.title('t-SNE plot')
    plt.xlabel('x-tsne')
    plt.ylabel('y_tsne')
    plt.show()

# %%
feature_cols=[col for col in fd001.columns if not col in ['id','cycle','setting3']]
active_features=feature_cols
plot_all_feature_distributions(x1_train_3D, samples_3D, active_features)
plot_correlation_difference(x1_train_3D, samples_3D)
compare_temporal_derivatives(x1_train_3D, samples_3D, sensor_idx=2)
# Out:
# Mean Correlation Error (Closer to 0 is better physics): 0.2149

# %%
visualization (x1_train_3D, samples_3D, 'tsne')
visualization (x1_train_3D, samples_3D, 'pca')
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 2000 samples in 0.001s...
# [t-SNE] Computed neighbors for 2000 samples in 0.060s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2000
# [t-SNE] Computed conditional probabilities for sample 2000 / 2000
# [t-SNE] Mean sigma: 0.380866
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 57.169868
# [t-SNE] KL divergence after 1000 iterations: 0.608813
